# %%
import numpy as np

# defining initial probabilities
p_birth = 0.3
p_death = 0.2
p_mutate = 0.1

# setting 'true' data parameters
theta_true = {
    "p_birth": p_birth,
    "p_death": p_death,
    "p_mutate": p_mutate
}

# defining steps function


# defining simulation
def simulate(theta, N_steps, N=60):
    p_birth = theta_true["p_birth"]
    p_death = theta_true["p_death"]
    p_mutate = theta_true["p_mutate"]

    # set up grid
    grid = np.zeros((N,N), dtype = int)
    grid[N//2, N//2] = 1 # setting up starting point at 1

    # total cells
    total_cells = []
    # total mutant cells
    total_mutant = []

    # setting up time loop
    for t in range(n_steps):
        total_cells.append((grid > 0).sum())
        mutant_cells.append((grid >0).sum())
        grid = step(grid, p_birth, p_death, p_mutate)

    return np.array(total_cells), np.array(mutant_cells)
